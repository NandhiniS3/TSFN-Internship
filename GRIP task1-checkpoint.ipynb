# %% [markdown]
# This page is for the purpose of GRIP tasks conducted by the Sparks Foundation.

# %% [markdown]
# Prediction using Supervised Machine Learning

# %%
#Importing all the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#importing the reference data
data='http://bit.ly/w-data'
r_data=pd.read_csv(data)
r_data.head(20)
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
